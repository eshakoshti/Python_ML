# %%
# Question 1 :
#What will be the output of the following code?

x=5
if x>3:
    print(x,"Grater than value")
    print("Done")

# Output : 5 is grater than value
# Out:
# 5 Grater than value
# Done

# %%
#  Question 2 :

#  You want to store your name, age, and your city in Python variables.
#  Write code to declare and print these variables.


name="Esha"
age=24
city="Ahemdabad"
print("Name:",name)
print("Age:",age)
print("city:",city)
# Out:
# Name: Savi
# Age: 24
# city: Ahemdabad

# %%
#  Question 3 :
#  Rewrite the following code by adding appropriate comments explaining what each part does:

num=10     # Assign value and store
sqaure=num*num  # Sqaure of Number
print("Sqaure of Number:",sqaure)  # print stastement
# Out:
# Sqaure of Number: 100

# %%
#   Question 4 :
#   How many statements are in the following line of Python code?
#   Explain what each statement does.
x=4 ; y = x+4 ; print(y)

# 3 statement are in  following line of python code
# x=4 : Assign value and store x variable
# y=x+4 : Addition of two value
# Print Statement return output
# Out:
# 8

# %%
# Question 5 :
# Is the following code valid in Python? If yes, what does it print?
# If no, explain the mistake.

a = 10 ; b = 20
print(a+b);

# yes 
# print :30
# Out:
# 30
