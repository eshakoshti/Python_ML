# %%
# bool
b=bool(10)
print(type(b))
# Out:
# <class 'bool'>

# %%
# bool using list

a=[10,20,30,40]
print(bool(a))
print((bool([])))
# Out:
# True
# False

# %%
# bool using tuple

a=[10,20,30,40,50,60]
print(bool(a))
print(bool(())) 
print(bool({}))
# Out:
# True
# False
# False

# %%
print(bool("welcome"))
print(bool(90))
# Out:
# True
# True
