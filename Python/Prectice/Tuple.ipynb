# %%
# Create Tuple
mytpl=('red','blue','yellow')
print(mytpl)
# Out:
# ('red', 'blue', 'yellow')

# %%
# Access tuple

mytpl=('red','blue','yellow')
print(mytpl[1])
print(mytpl[-3])
# Out:
# blue
# red

# %%
# Add Item

mytpl=('red','blue','yellow')
m=list(mytpl)
m.append('pink')
print(m)
# Out:
# ['red', 'blue', 'yellow', 'pink']

# %%
mytpl=('red','blue','yellow','pink')
m=list(mytpl)
m.remove('red')
print(m)
# Out:
# ['blue', 'yellow', 'pink']

# %%
 # join() method

mytpl=('red','blue','yellow')
mytpl1=(11,22,33,44,66,88,99)
result=mytpl+mytpl1
print(result)
# Out:
# ('red', 'blue', 'yellow', 11, 22, 33, 44, 66, 88, 99)

# %%
# count() method
mytpl1=(11,22,33,44,66,88,99,22,88,11,11)
x=mytpl1 .count(11)
print(x)
# Out:
# 3

# %%
# 

mytpl=('red','blue','yellow')
(mango,orange,apple) = mylist
print(mango)
print(orange)
print(apple)
# Out:
# apple
# mengo
# orange

# %%
# Using Loop
#  
mylist1=(2,3,4,5,7,8,8)
for i in mylist1:
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 7
# 8
# 8

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 mytpl=('red','blue','yellow')
# ----> 2 mytpl(key=str.upper)
#       3 print("mytpl")
#
# TypeError: 'tuple' object is not callable
